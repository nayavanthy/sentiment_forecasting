# %%
import gensim.downloader as api
import spacy
import re
import concurrent.futures

# Load spaCy NLP Model
print("Loading spaCy NLP model...")
nlp = spacy.load("en_core_web_md")  # Medium-sized model with word vectors
print("spaCy Model Loaded!")

# Load a Higher-Dimensional Pre-trained Word Embedding Model
print("Loading Word Embeddings (GloVe)...")
word2vec_model = api.load("glove-wiki-gigaword-300")  # More accurate embeddings
print("Word Embeddings Loaded!")

def get_word2vec_similar_words(word, top_n=10):
    """Fetches similar words from GloVe embeddings."""
    try:
        if word in word2vec_model:
            return [w for w, _ in word2vec_model.most_similar(word, topn=top_n)]
        elif word.lower() in word2vec_model:
            return [w for w, _ in word2vec_model.most_similar(word.lower(), topn=top_n)]
    except KeyError:
        return []
    return []

def extract_relevant_words(text):
    """Extracts important words using NLP without manual intervention."""
    doc = nlp(text)
    
    # Keep only meaningful nouns and proper nouns
    relevant_words = {token.lemma_ for token in doc if token.pos_ in {"NOUN", "PROPN"}}
    
    return list(relevant_words)  # Return unique words

def filter_hashtag_phrases(phrases):
    """Filters phrases dynamically based on frequency and length."""
    
    # Exclude common generic words using GloVe similarity scores
    filtered_phrases = [
        phrase for phrase in phrases 
        if 2 <= len(phrase) <= 25 and phrase in word2vec_model
    ]
    
    return filtered_phrases

def format_hashtag(text):
    """Formats text into a proper hashtag."""
    text = re.sub(r'[^a-zA-Z0-9 ]', '', text.strip())  # Remove special characters
    words = text.split()
    
    if not words:
        return None

    return "#" + "".join(word.capitalize() for word in words)

def generate_hashtags(topic, max_hashtags=15):
    """Generates meaningful hashtags for a given topic."""
    print(f"Generating hashtags for: {topic}\n")
    
    # Extract important words (nouns, proper nouns) from the topic
    relevant_words = extract_relevant_words(topic)
    relevant_words.append(topic)  # Ensure the original topic is included
    
    with concurrent.futures.ThreadPoolExecutor() as executor:
        future_w2v = executor.map(get_word2vec_similar_words, relevant_words)
        
    similar_words = set()
    for word_list in future_w2v:
        similar_words.update(word_list)
    
    # Filter and format hashtags
    all_phrases = filter_hashtag_phrases(similar_words)
    formatted_hashtags = list(filter(None, [format_hashtag(phrase) for phrase in all_phrases]))
    
    return formatted_hashtags[:max_hashtags]

if __name__ == "__main__":
    input_word = input("Enter a topic: ")
    hashtags = generate_hashtags(input_word)
    print("\nGenerated Hashtags:")
    for tag in hashtags:
        print(tag)

# %%
import gensim.downloader as api
import spacy
import re
import concurrent.futures

# Load spaCy NLP Model
print("Loading spaCy NLP model...")
nlp = spacy.load("en_core_web_md")  # Medium-sized model with word vectors
print("spaCy Model Loaded!")

# Load a Higher-Dimensional Pre-trained Word Embedding Model
print("Loading Word Embeddings (GloVe)...")
word2vec_model = api.load("glove-wiki-gigaword-300")  # More accurate embeddings
print("Word Embeddings Loaded!")

def get_word2vec_similar_words(word, top_n=10):
    """Fetches similar words from GloVe embeddings."""
    try:
        if word in word2vec_model:
            return [w for w, _ in word2vec_model.most_similar(word, topn=top_n)]
        elif word.lower() in word2vec_model:
            return [w for w, _ in word2vec_model.most_similar(word.lower(), topn=top_n)]
    except KeyError:
        return []
    return []

def extract_relevant_words(text):
    """Extracts important words using NLP without manual intervention."""
    doc = nlp(text)
    
    # Keep only meaningful nouns and proper nouns
    relevant_words = {token.lemma_ for token in doc if token.pos_ in {"NOUN", "PROPN"}}
    
    return list(relevant_words)  # Return unique words

def filter_hashtag_phrases(phrases):
    """Filters phrases dynamically based on frequency and length."""
    
    # Exclude common generic words using GloVe similarity scores
    filtered_phrases = [
        phrase for phrase in phrases 
        if 2 <= len(phrase) <= 25 and phrase in word2vec_model
    ]
    
    return filtered_phrases

def format_hashtag(text):
    """Formats text into a proper hashtag."""
    text = re.sub(r'[^a-zA-Z0-9 ]', '', text.strip())  # Remove special characters
    words = text.split()
    
    if not words:
        return None

    return "#" + "".join(word.capitalize() for word in words)

def generate_hashtags(topic, max_hashtags=15):
    """Generates meaningful hashtags for a given topic."""
    print(f"\nGenerating hashtags for: {topic}\n")
    
    # Extract important words (nouns, proper nouns) from the topic
    relevant_words = extract_relevant_words(topic)
    relevant_words.append(topic)  # Ensure the original topic is included
    
    with concurrent.futures.ThreadPoolExecutor() as executor:
        future_w2v = executor.map(get_word2vec_similar_words, relevant_words)
        
    similar_words = set()
    for word_list in future_w2v:
        similar_words.update(word_list)
    
    # Filter and format hashtags
    all_phrases = filter_hashtag_phrases(similar_words)
    formatted_hashtags = list(filter(None, [format_hashtag(phrase) for phrase in all_phrases]))
    
    return formatted_hashtags[:max_hashtags]

if __name__ == "__main__":
    # Ask user for 5 topics
    test_topics = [input(f"Enter topic {i+1}: ") for i in range(5)]

    # Loop through all topics and generate hashtags
    for topic in test_topics:
        hashtags = generate_hashtags(topic)
        print("\nGenerated Hashtags:")
        for tag in hashtags:
            print(tag)
        print("-" * 40)  # Separator for clarity
# Out:
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
# Loading spaCy NLP model...
# spaCy Model Loaded!
# Loading Word Embeddings (GloVe)...
# Word Embeddings Loaded!
# Enter topic 1:  travel
# Enter topic 2:  sports
# Enter topic 3:  climate
# Enter topic 4:  food
# Enter topic 5:  google
# Generating hashtags for: travel
#
#
# Generated Hashtags:
# #Trips
# #Traveling
# #Travelling
# #Trip
# #Vacation
# #Travels
# #Travellers
# #Travelers
# #Destinations
# #Flights
# ----------------------------------------
#
# Generating hashtags for: sports
#
#
# Generated Hashtags:
# #Football
# #Athlete
# #Entertainment
# #Athletics
# #Sports
# #Racing
# #Soccer
# #Sport
# #Recreational
# #Cycling
# #Athletes
# #Sporting
# #Compete
# #Baseball
# #Athletic
# ----------------------------------------
#
# Generating hashtags for: climate
#
#
# Generated Hashtags:
# #Climatic
# #Environment
# #Climates
# #Environmental
# #Warming
# #Weather
# #Greenhouse
# #Change
# #Global
# #Biodiversity
# ----------------------------------------
#
# Generating hashtags for: food
#
#
# Generated Hashtags:
# #Supplies
# #Meal
# #Meat
# #Vegetables
# #Eat
# #Eating
# #Meals
# #Foods
# #Products
# #Nutrition
# ----------------------------------------
#
# Generating hashtags for: google
#
#
# Generated Hashtags:
# #Netscape
# #Yahoo
# #Aol
# #Online
# #Microsoft
# #Ebay
# #Internet
# #Web
# #Youtube
# #Facebook
# ----------------------------------------
